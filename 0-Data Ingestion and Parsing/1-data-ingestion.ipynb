# %% [markdown]
# ## Table of Contents of the course
#
# - Introduction to Data Ingestion
# - Text Files (.txt)
# - PDF Documents
# - Microsoft Word Documents
# - CSV and Excel Files
# - JSON and Structured Data
# - Web Scraping
# - Databases (SQL)
# - Audio and Video Transcripts
# - Advanced Techniques
# - Best Practices

# %% [markdown]
# ### Introduction To Data Ingestion

# %%
import os
from typing import List, Dict, Any

# %%
from langchain.text_splitter import(
    RecursiveCharacterTextSplitter,
    CharacterTextSplitter,
    TokenTextSplitter
)           
from langchain.schema import Document

# %% [markdown]
# ### Document Structure In Langchain

# %%
## A document is a simple object that contains a page content and metadata.
### Document Structure In Langchain
# Why metadata matters:
    ## Metadata is crucial for:
        ##Filtering search results
        ##Tracking document sources
        ##Providing context in response
        ##Debugging and auditing

doc=Document(
    page_content="This is the main text content that will be embedded and searched.",
    metadata={
        "source":"book.txt",
        "page":2,
        "author":"Hammad Ali Tahir",
        "date_created":"2026-01-01",
        "cutom_field":"any_value"

    }
)
print("Document Structure")

print(f"Content :{doc.page_content}")
print(f"Metadata :{doc.metadata}")
# Out:
# Document Structure
# Content :This is the main text content that will be embedded and searched.
# Metadata :{'source': 'book.txt', 'page': 2, 'author': 'Hammad Ali Tahir', 'date_created': '2026-01-01', 'cutom_field': 'any_value'}

# %%
type(doc)
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ### Text Files (.txt) - The Simplest Case {#2-text-files}

# %%
## Create a simple txt file
import os
os.makedirs("data/text_files",exist_ok=True)

# %%
## Now writting some text in those files
## There are two sample text files
sample_texts={
    "data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample text files created!")
# Out:
# Sample text files created!

# %% [markdown]
# ### TextLoader- Read Single File

# %%
from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader

## Loading a single text file
loader=TextLoader("data/text_files/python_intro.txt", encoding="utf-8")

documents=loader.load()
print(f"📄 Loaded {len(documents)} document")
print(f"Content preview: {documents[0].page_content[:100]}...")
print(f"Metadata: {documents[0].metadata}")
# Out:
# 📄 Loaded 1 document
# Content preview: Python Programming Introduction
#
# Python is a high-level, interpreted programming language known for ...
# Metadata: {'source': 'data/text_files/python_intro.txt'}

# %% [markdown]
# #### Reading file made outside

# %%
loader=TextLoader("data/output.txt", encoding="utf-8")

output_documents=loader.load()
print(f"📄 Loaded {len(output_documents)} document")
print(f"Content preview: {output_documents[0].page_content[:1000]}....")
print(f"Metadata: {output_documents[0].metadata}")
# Out:
# 📄 Loaded 1 document
# Content preview:
#         Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer
#         Explanation: With Labour trailing Nigel Farage's populist Reform UK in the polls, UK PM Starmer faces difficult state spending and tax choices.
#
#
#
#         Date: 05 Sep, 2025 09:40pm
#         Title: Justice Shah asks CJP Afridi to publicly answer 6 questions on ‘pressing institutional concerns’
#         Explanation: Says he trusts CJP to use Sept 8 judicial conference as a “moment of institutional renewal by answering these questions and reaffirming the principles of collegiality and constitutional fidelity”.
#
#
#
#         Date: 05 Sep, 2025 07:25pm
#         Title: Imran Khan’s other nephew Shershah also released from Kot Lakhpat jail after bail
#         Explanation: Shershah's brother Shahrez was set free from prison after being granted bail a day earlier.
#
#
#
#         Date: 05 Sep, 2025 07:05pm
#         Title: ‘Roblox’ game to impose age controls ....
# Metadata: {'source': 'data/output.txt'}

# %% [markdown]
# ### DirectoryLoader- Multiple Text Files
# Loading both files from text_files

# %%
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "data/text_files",
    glob="**/*.txt", ## Pattern to match files......As we want to load all the text files in the directory and its subdirectories, 
                                                                    ## So we use the glob pattern **/*.txt
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'}, ##kwargs to pass to the loader class
    show_progress=True
)

documents=dir_loader.load()

print(f" Loaded {len(documents)} documents")
for i, doc in enumerate(documents):
    print(f"\nDocument {i+1}:")
    print(f"  Source: {doc.metadata['source']}")
    print(f"  Length: {len(doc.page_content)} characters")


# 📊 Analysis
print("\n DirectoryLoader Characteristics:")
print(" Advantages:")
print("  - Loads multiple files at once")
print("  - Supports glob patterns")
print("  - Progress tracking")
print("  - Recursive directory scanning")

print("\n Disadvantages:")
print("  - All files must be same type")
print("  - Limited error handling per file")
print("  - Can be memory intensive for large directories")
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 2273.95it/s]
#  Loaded 2 documents
#
# Document 1:
#   Source: data/text_files/python_intro.txt
#   Length: 489 characters
#
# Document 2:
#   Source: data/text_files/machine_learning.txt
#   Length: 575 characters
#
#  DirectoryLoader Characteristics:
#  Advantages:
#   - Loads multiple files at once
#   - Supports glob patterns
#   - Progress tracking
#   - Recursive directory scanning
#
#  Disadvantages:
#   - All files must be same type
#   - Limited error handling per file
#   - Can be memory intensive for large directories

# %% [markdown]
# ### Text Splitting Statergies

# %%
### Different text splitting strategies
from langchain.text_splitter import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,
    TokenTextSplitter
)
print(output_documents)
# Out:
# [Document(metadata={'source': 'data/output.txt'}, page_content='\n        Date: 05 Sep, 2025 09:03pm\n        Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer\n        Explanation: With Labour trailing Nigel Farage\'s populist Reform UK in the polls, UK PM Starmer faces difficult state spending and tax choices.\n \n     \n\n        Date: 05 Sep, 2025 09:40pm\n        Title: Justice Shah asks CJP Afridi to publicly answer 6 questions on ‘pressing institutional concerns’\n        Explanation: Says he trusts CJP to use Sept 8 judicial conference as a “moment of institutional renewal by answering these questions and reaffirming the principles of collegiality and constitutional fidelity”.\n \n     \n\n        Date: 05 Sep, 2025 07:25pm\n        Title: Imran Khan’s other nephew Shershah also released from Kot Lakhpat jail after bail\n        Explanation: Shershah\'s brother Shahrez was set free from prison after being granted bail a day earlier.\n \n     \n\n        Date: 05 Sep, 2025 07:05pm\n        Title: ‘Roblox’ game to impose age controls this year\n        Explanation: Company aims to combine estimates of users\' ages, checks on official IDs and parental consent to limit communication between adults and minors.\n \n     \n\n        Date: 05 Sep, 2025 07:08pm\n        Title: WHO chief lifts global mpox emergency\n        Explanation: Dr Tedros Adhanom Ghebreyesus says decision taken in light of declining cases and deaths.\n \n     \n\n        Date: 05 Sep, 2025 05:52pm\n        Title: Saba Qamar’s Case No. 9 is about a rape victim’s search for justice and it looks intense\n        Explanation: The first look of the upcoming TV show is out and it features a story we know all too well.\n \n     \n\n        Date: 05 Sep, 2025 06:54pm\n        Title: Trump says India and Russia appear ‘lost’ to ‘deepest, darkest China’\n        Explanation: Asked about Trump’s post, Indian foreign ministry spokesperson says he has no comment; India plans relief package for exporters hit by US tariffs.\n \n     \n\n        Date: 05 Sep, 2025 05:08pm\n        Title: Diplomatic tour de force: China’s Xi shows he’s ‘totally in charge’\n        Explanation: Analysts say Xi’s whirlwind of activity underscores China’s ambition in presenting itself as reliable partner to developing nations on global stage.\n \n     \n\n        Date: 05 Sep, 2025 06:10pm\n        Title: PSX crosses 154,000 points amid investor optimism despite flood-related risks\n        Explanation: Analyst notes "incipient euphoria", cautions against underestimating flood-related concerns.\n \n     \n\n        Date: 05 Sep, 2025 05:02pm\n        Title: This year’s Toronto International Film Festival will screen five films on Palestine\n        Explanation: The festival\'s 50th edition will run for 11 days and showcase 292 films --- including many from the Middle East.\n \n     \n\n        Date: 05 Sep, 2025 04:13pm\n        Title: Powerhouse Australia ‘up for challenge’ of defending ICC Women’s World Cup\n        Explanation: National selector says extended nature of ODI World Cup can be a challenge but group has depth and versatility to meet those demands.\n \n     \n\n        Date: 05 Sep, 2025 08:01pm\n        Title: FO spokesperson says future of refugees ‘up to Pakistan’\n        Explanation: Shafqat Ali Khan says Afghan refugees waiting to travel to Germany should leave as soon as possible.\n \n     \n\n        Date: 05 Sep, 2025 04:05pm\n        Title: Traditional flavours highlight Malaysia’s diversity at food festival in Islamabad\n        Explanation: A wide selection of appetisers, mains, and desserts prepared by Malaysian chefs are available from Sept 4 to 10.\n \n     \n\n        Date: 05 Sep, 2025 03:59pm\n        Title: PMD warns of urban flooding in low-lying areas of Karachi, other Sindh cities from Sept 7-9\n        Explanation: Strong monsoon currents are likely to penetrate Sindh and eastern Punjab from Sept 6 onwards.\n \n     \n\n     ...

# %%
### MEthod 1- Character Text Splitter
text=output_documents[0].page_content
print(text)
# Out:
#         Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer
#         Explanation: With Labour trailing Nigel Farage's populist Reform UK in the polls, UK PM Starmer faces difficult state spending and tax choices.
#
#
#
#         Date: 05 Sep, 2025 09:40pm
#         Title: Justice Shah asks CJP Afridi to publicly answer 6 questions on ‘pressing institutional concerns’
#         Explanation: Says he trusts CJP to use Sept 8 judicial conference as a “moment of institutional renewal by answering these questions and reaffirming the principles of collegiality and constitutional fidelity”.
#
#
#
#         Date: 05 Sep, 2025 07:25pm
#         Title: Imran Khan’s other nephew Shershah also released from Kot Lakhpat jail after bail
#         Explanation: Shershah's brother Shahrez was set free from prison after being granted bail a day earlier.
#
#
#
#         Date: 05 Sep, 2025 07:05pm
#         Title: ‘Roblox’ game to impose age controls this year
#         Explanation: Company aims to combine estimates of users' ages, checks on official IDs and parental consent to limit communication between adults and minors.
#
#
#
#         Date: 05 Sep, 2025 07:08pm
#         Title: WHO chief lifts global mpox emergency
#         Explanation: Dr Tedros Adhanom Ghebreyesus says decision taken in light of declining cases and deaths.
#
#
#
#         Date: 05 Sep, 2025 05:52pm
#         Title: Saba Qamar’s Case No. 9 is about a rape victim’s search for justice and it looks intense
#         Explanation: The first look of the upcoming TV show is out and it features a story we know all too well.
#
#
#
#         Date: 05 Sep, 2025 06:54pm
#         Title: Trump says India and Russia appear ‘lost’ to ‘deepest, darkest China’
#         Explanation: Asked about Trump’s post, Indian foreign ministry spokesperson says he has no comment; India plans relief package for exporters hit by US tariffs.
#
#
#
#         Date: 05 Sep, 2025 05:08pm
#         Title: Diplomatic tour de force: China’s Xi shows he’s ‘totally in charge’
#         Explanation: Analysts say Xi’s whirlwind of activity underscores China’s ambition in presenting itself as reliable partner to developing nations on global stage.
#
#
#
#         Date: 05 Sep, 2025 06:10pm
#         Title: PSX crosses 154,000 points amid investor optimism despite flood-related risks
#         Explanation: Analyst notes "incipient euphoria", cautions against underestimating flood-related concerns.
#
#
#
#         Date: 05 Sep, 2025 05:02pm
#         Title: This year’s Toronto International Film Festival will screen five films on Palestine
#         Explanation: The festival's 50th edition will run for 11 days and showcase 292 films --- including many from the Middle East.
#
#
#
#         Date: 05 Sep, 2025 04:13pm
#         Title: Powerhouse Australia ‘up for challenge’ of defending ICC Women’s World Cup
#         Explanation: National selector says extended nature of ODI World Cup can be a challenge but group has depth and versatility to meet those demands.
#
#
#
#         Date: 05 Sep, 2025 08:01pm
#         Title: FO spokesperson says future of refugees ‘up to Pakistan’
#         Explanation: Shafqat Ali Khan says Afghan refugees waiting to travel to Germany should leave as soon as possible.
#
#
#
#         Date: 05 Sep, 2025 04:05pm
#         Title: Traditional flavours highlight Malaysia’s diversity at food festival in Islamabad
#         Explanation: A wide selection of appetisers, mains, and desserts prepared by Malaysian chefs are available from Sept 4 to 10.
#
#
#
#         Date: 05 Sep, 2025 03:59pm
#         Title: PMD warns of urban flooding in low-lying areas of Karachi, other Sindh cities from Sept 7-9
#         Explanation: Strong monsoon currents are likely to penetrate Sindh and eastern Punjab from Sept 6 onwards.
#
#
#
#         Date: 05 Sep, 2025 03:29pm
#         Title: India blocks Austrian economist’s X account over ‘dismantle India’ post: report
#         Explanation: The economist shared a map showing Khalistan carved out of India.
#
#
#
#         Date: 05 Sep, 2025 09:41pm
#         Title: Two women held for hurling egg at Imran Khan’s sister Aleema in Rawalpindi: police
#         Explanation: Footage of incident shows expression of shock on Aleema's face; PTI alleges police facilitation, says women were sent “as part of an agenda”.
#
#
#
#         Date: 05 Sep, 2025 02:19pm
#         Title: Daniel Levy makes shock decision to quit as Tottenham chairman after nearly 25 years
#         Explanation: Levy, who was the longest-serving chairman in the Premier League, had come under fire more than ever over the last few seasons.
#
#
#
#         Date: 05 Sep, 2025 05:44pm
#         Title: Govt, PTI spar in National Assembly over federal flood relief
#         Explanation: PTI chairman claims NDMA is not doing enough in Khyber Pakhtunkhwa; Tallal Chaudhry expresses willingness for talks on Balochistan issues.
#
#
#
#         Date: 05 Sep, 2025 01:55pm
#         Title: New recipes help Pakistani mothers ward off malnutrition
#         Explanation: In Sindh, 48pc of children under five suffer from malnutrition and 20pc from its most severe form called "wasting".
#
#
#
#         Date: 05 Sep, 2025 12:45pm
#         Title: US AI giant Anthropic bars Chinese-owned entities
#         Explanation: Companies based in China, Russia, North Korea, and Iran are already unable to access its commercial services over legal and security concerns.
#
#
#
#         Date: 05 Sep, 2025 12:44pm
#         Title: Floyd Mayweather Jr, Mike Tyson agree to exhibition fight in 2026
#         Explanation: Boxing legends Floyd Mayweather Jr. and Mike Tyson are set to square off in an exhibition boxing match next spring,...
#
#
#
#         Date: 05 Sep, 2025 12:29pm
#         Title: Italy’s King of Fashion, Giorgio Armani, forever changed the way we look at jackets
#         Explanation: The self-made fashion mogul leaves behind a legacy of innovative style and dedication to his craft.
#
#
#
#         Date: 05 Sep, 2025 11:34am
#         Title: Punjab CM under fire for sharing two-year-old photo of portable toilet ‘for flood-hit people’
#         Explanation: Social media users spot that the photo was taken from the website of an online marketplace.
#
#
#
#         Date: 05 Sep, 2025 11:22am
#         Title: Singer Quratulain Balouch injured in brown bear attack during Skardu camping trip
#         Explanation: She was shifted to the RHQ Hospital Skardu where doctors said she is out of danger.
#
#
#
#         Date: 05 Sep, 2025 10:50am
#         Title: Sabalenka returns to US Open final as Anisimova sinks Osaka
#         Explanation: The 27-year-old from Belarus is through to her third successive US Open final.
#
#
#
#         Date: 05 Sep, 2025 10:02am
#         Title: Floods spark agri-emergency call as vast rice, cotton crops ruined with losses ‘in billions’
#         Explanation: Pakistan Business Forum warns 60pc of rice, 35pc of cotton and 30pc of sugarcane lost in Punjab; calls for loans, reforms.
#
#
#
#         Date: 05 Sep, 2025 09:56am
#         Title: Judges ‘allowed themselves to be used’ in Bhutto case: Justice Minallah
#         Explanation: Praises those who stuck to their principles despite all odds.
#
#
#
#         Date: 05 Sep, 2025 09:45am
#         Title: UK, UN announce aid as country reels from floods
#         Explanation: UK announces another £1.2m for Sindh; UN allocates $600,000 from Regional Humanitarian Fund.
#
#
#
#         Date: 05 Sep, 2025 09:41am
#         Title: Trump rebrands Department of Defence as ‘Department of War’
#         Explanation: According to the White House, the name change “conveys a stronger message of readiness and resolve".
#
#
#
#         Date: 05 Sep, 2025 12:38pm
#         Title: 3 children killed, 5 injured as dumper truck runs them over in Abbottabad: police
#         Explanation: An FIR has been registered against the driver who fled the scene, and the dumper has been seized.
#
#
#
#         Date: 05 Sep, 2025 09:24am
#         Title: In seeking to protect children we must not build cages — digital or otherwise
#         Explanation: Facebook, Instagram, YouTube and TikTok carry their own insidious risks.
#
#
#
#         Date: 05 Sep, 2025 09:16am
#         Title: South Punjab still not out of the woods as high flood warning issued for Kasur, Okara, other cities
#         Explanation: More than 400,000 relocated; over 85 Sialkot villages cut off since Aug 26.
#
#
#
#         Date: 05 Sep, 2025 11:06am
#         Title: SHO among three cops martyred in Karak attack
#
#         Explanation: Police party ambushed by armed men when it was proceeding to a petrol pump.
#
#
#
#         Date: 05 Sep, 2025 11:08am
#         Title: 30 arrested in Kurram search operation
#
#         Explanation: The house of the main suspect involved in Wednesday’s attack on a vehicle also demolished.
#
#
#
#         Date: 05 Sep, 2025 02:02pm
#         Title: Politics of boycott is not only harmful for democracy, it’s also useless for the party adopting it
#         Explanation: Traditionally, rival parties sat together in times of emergency. Not anymore, it seems.
#
#
#
#         Date: 05 Sep, 2025 11:11am
#         Title: Elite Force deployed at Babusar Top, Kaghan valley
#
#         Explanation: DPO says nighttime convoy system already in place for safety of travellers.
#
#
#
#         Date: 05 Sep, 2025 11:13am
#         Title: CDA approves projects to tackle water shortage, upgrade sports grounds
#
#         Explanation: DWP also okays PC-I for construction of RCC sewer in low-lying areas from Rawat T. Chowk to Soan River.
#
#
#
#         Date: 05 Sep, 2025 08:30am
#         Title: Editorial: Govt must be held accountable for role amid floods — not just in rhetoric, but in presence
#         Explanation: All political parties must recognise that disaster is not a moment for politicking, but a test of governance.
#
#
#
#         Date: 05 Sep, 2025 11:34am
#         Title: Over 100 million Pakistanis overweight: health experts
#
#         Explanation: Experts at Islamabad moot say chronic obesity fuelling alarming rise in diabetes, heart attacks, strokes, cancers.
#
#
#
#         Date: 05 Sep, 2025 11:44am
#         Title: Journalists, rights activists decry curbs on press freedom
#
#         Explanation: Candlelight vigil held outside Dawn offices to pay homage to veteran journalists Nisar Osmani and CR Shamsi.
#
#
#
#         Date: 05 Sep, 2025 10:45am
#         Title: More villages at risk as Ravi, Nullah Baen erode land in Shakargarh
#
#         Explanation: Locals were facing massive losses due to breach of Baen's protective embankment, resident says.
#
#
#
#         Date: 05 Sep, 2025 10:56am
#         Title: Hundreds waiting to be rescued in Ahmedpur Sial
#         Explanation: Local politician alleges that situation created due to wrong breach; Jhang district administration says over 100 boats being used in rescue operations.
#
#
#
#         Date: 05 Sep, 2025 11:01am
#         Title: Heavy rains across Sindh from Sunday to Tuesday
#         Explanation: Torrential rains may cause urban flooding in low-lying areas, PMD warns.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: SHC voids KMC move to rent  out nine parks, playgrounds
#
#         Explanation: City Council resolution authorising the corporation to rent out the amenity plots also overturned.
#
#
#
#         Date: 05 Sep, 2025 11:12am
#         Title: We don’t have tracks strong enough to run fast trains, says Hanif Abbasi
#
#         Explanation: Railways minister shares PR’s plan to outsource 38 trains, eight hospitals and 14 schools.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: UN body finds US, UAE responsible for Afghan refugee’s arbitrary detention
#
#         Explanation: 5-member Working Group asks both states to provide compensation and reparations.
#
#
#
#         Date: 05 Sep, 2025 12:02pm
#         Title: Trump tells Europe to put economic pressure on China
#
#         Explanation: Zelensky says discussed sanctions on Russia and protecting Ukraine’s airspace in call.
#
#
#
#         Date: 05 Sep, 2025 12:11pm
#         Title: Death toll rises to 16 in Lisbon funicular crash
#
#         Explanation: The dead included two South Koreans and a Swiss national; 11 foreigners were among the injured.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: Norway tests electric plane
#
#         Explanation: Flight takes 55 minutes and simulated a cargo flight route in south-eastern Norway.
#
#
#
#         Date: 05 Sep, 2025 10:43am
#         Title: Fakhar and Abrar star as Pakistan beat UAE to reach tri-series final
#
#         Explanation: The win not only took Pakistan to Sunday’s final but also ensured Afghanistan who face the hosts in the last group on Friday, would advance.
#
#
#
#         Date: 05 Sep, 2025 11:34am
#         Title: FIFA to use dynamic pricing for World Cup ticket sales
#
#         Explanation: Tickets for group-stage matches will start at $60, with pricing for later stages, including the final, reaching up to $6,730.
#
#
#
#         Date: 05 Sep, 2025 10:03am
#         Title: Maritime joint ventures with China explored
#         Explanation: Shandong Xinxu proposes integrated maritime complex in Pakistan.
#
#
#
#         Date: 05 Sep, 2025 02:01pm
#         Title: K-Electric sukuk IPO oversubscribed by 2.2 times; raises Rs2bn
#         Explanation: Utility terms sukuk IPO "significant step" towards Islamic finance at household and individual level.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: Services exports rise 18.3pc in July
#
#         Explanation: IT-related services lead a 23.8pc rise in telecom, computer, and information exports.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: VEON to acquire TPL Insurance
#
#         Explanation: Acquisition will enable Jazz to offer tailored insurance products.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: SBP reserves rise by $28m to $14.3bn
#
#         Explanation: Increase reflects growing stability in country’s external account.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: PPL strikes major oil, gas discovery
#
#         Explanation: Company terms discovery "major milestone for both PPL and its joint venture partner".
#
#
#
#         Date: 05 Sep, 2025 10:29am
#         Title: PSX hits new highs despite flood concerns
#
#         Explanation: Index gains 464 po­­ints, maint­a­ining its upward trajectory amid strong institutional interest and positive economic signals.
#
#
#
#         Date: 05 Sep, 2025 10:52am
#         Title: Two tribesmen shot dead in Surab
#
#         Explanation: Levies launch probe, conducting raids to arrest attackers.
#
#
#
#         Date: 05 Sep, 2025 08:01pm
#         Title: FO spokesperson says future of refugees ‘up to Pakistan’
#         Explanation: Shafqat Ali Khan says Afghan refugees waiting to travel to Germany should leave as soon as possible.
#
#
#
#         Date: 05 Sep, 2025 09:40pm
#         Title: Justice Shah asks CJP Afridi to publicly answer 6 questions on ‘pressing institutional concerns’
#         Explanation: Says he trusts CJP to use Sept 8 judicial conference as a “moment of institutional renewal by answering these questions and reaffirming the principles of collegiality and constitutional fidelity”.
#
#
#
#         Date: 05 Sep, 2025 09:41pm
#         Title: Two women held for hurling egg at Imran Khan’s sister Aleema in Rawalpindi: police
#         Explanation: Footage of incident shows expression of shock on Aleema's face; PTI alleges police facilitation, says women were sent “as part of an agenda”.
#
#
#
#         Date: 05 Sep, 2025 05:44pm
#         Title: Govt, PTI spar in National Assembly over federal flood relief
#         Explanation: PTI chairman claims NDMA is not doing enough in Khyber Pakhtunkhwa; Tallal Chaudhry expresses willingness for talks on Balochistan issues.
#
#
#
#         Date: 05 Sep, 2025 07:25pm
#         Title: Imran Khan’s other nephew Shershah also released from Kot Lakhpat jail after bail
#         Explanation: Shershah's brother Shahrez was set free from prison after being granted bail a day earlier.
#
#
#
#         Date: 05 Sep, 2025 09:16am
#         Title: South Punjab still not out of the woods as high flood warning issued for Kasur, Okara, other cities
#         Explanation: More than 400,000 relocated; over 85 Sialkot villages cut off since Aug 26.
#
#
#
#         Date: 05 Sep, 2025 12:38pm
#         Title: 3 children killed, 5 injured as dumper truck runs them over in Abbottabad: police
#         Explanation: An FIR has been registered against the driver who fled the scene, and the dumper has been seized.
#
#
#
#         Date: 05 Sep, 2025 10:58am
#         Title: Two security personnel martyred in Swat
#
#         Explanation: A security official confirms the presence of up to 60 militants in Khawazkhela and Matta tehsils.
#
#
#
#         Date: 05 Sep, 2025 09:00am
#         Title: Opposition  calls strike in Balochistan  on Sept 8
#
#         Explanation: Leaders from six parties warn of threats to democratic politics and provincial leadership.
#
#
#
#         Date: 05 Sep, 2025 12:15pm
#         Title: IHC larger bench to examine validity of Aafia Siddiqui’s case proceedings
#         Explanation: Four judges to consider three key questions raised by registrar’s office while transferring the case.
#
#
#
#         Date: 05 Sep, 2025 10:55am
#         Title: CJP Afridi briefed on advancements in SC reform agenda
#         Explanation: Out of 89 identified initiatives, 30 have been fully implemented, 44 are in progress.
#
#
#
#         Date: 05 Sep, 2025 11:34am
#         Title: Over 100 million Pakistanis overweight: health experts
#
#         Explanation: Experts at Islamabad moot say chronic obesity fuelling alarming rise in diabetes, heart attacks, strokes, cancers.
#
#
#
#         Date: 05 Sep, 2025 10:35am
#         Title: Ex-PM Shahid Khaqan Abbasi blames govt for sugar crisis
#         Explanation: Accuses NAB of protecting corrupt business practices instead of holding mill owners accountable.
#
#
#
#         Date: 05 Sep, 2025 09:56am
#         Title: Judges ‘allowed themselves to be used’ in Bhutto case: Justice Minallah
#         Explanation: Praises those who stuck to their principles despite all odds.
#
#
#
#         Date: 05 Sep, 2025 11:44am
#         Title: Journalists, rights activists decry curbs on press freedom
#
#         Explanation: Candlelight vigil held outside Dawn offices to pay homage to veteran journalists Nisar Osmani and CR Shamsi.
#
#
#
#         Date: 05 Sep, 2025 07:53am
#         Title: Floods prompt ECP to postpone by-elections
#
#         Explanation: Commission says new schedule to be issued once situation improves.
#
#
#
#         Date: 05 Sep, 2025 11:34am
#         Title: Punjab CM under fire for sharing two-year-old photo of portable toilet ‘for flood-hit people’
#         Explanation: Social media users spot that the photo was taken from the website of an online marketplace.
#
#
#
#         Date: 05 Sep, 2025 11:11am
#         Title: Elite Force deployed at Babusar Top, Kaghan valley
#
#         Explanation: DPO says nighttime convoy system already in place for safety of travellers.
#
#
#
#         Date: 05 Sep, 2025 11:12am
#         Title: We don’t have tracks strong enough to run fast trains, says Hanif Abbasi
#
#         Explanation: Railways minister shares PR’s plan to outsource 38 trains, eight hospitals and 14 schools.
#
#
#
#         Date: 05 Sep, 2025 11:13am
#         Title: CDA approves projects to tackle water shortage, upgrade sports grounds
#
#         Explanation: DWP also okays PC-I for construction of RCC sewer in low-lying areas from Rawat T. Chowk to Soan River.
#
#
#
#         Date: 05 Sep, 2025 10:45am
#         Title: More villages at risk as Ravi, Nullah Baen erode land in Shakargarh
#
#         Explanation: Locals were facing massive losses due to breach of Baen's protective embankment, resident says.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: SHC voids KMC move to rent  out nine parks, playgrounds
#
#         Explanation: City Council resolution authorising the corporation to rent out the amenity plots also overturned.
#
#
#
#         Date: 05 Sep, 2025 11:08am
#         Title: 30 arrested in Kurram search operation
#
#         Explanation: The house of the main suspect involved in Wednesday’s attack on a vehicle also demolished.
#
#
#
#         Date: 05 Sep, 2025 11:06am
#         Title: SHO among three cops martyred in Karak attack
#
#         Explanation: Police party ambushed by armed men when it was proceeding to a petrol pump.
#
#
#
#         Date: 05 Sep, 2025 10:52am
#         Title: Two tribesmen shot dead in Surab
#
#         Explanation: Levies launch probe, conducting raids to arrest attackers.
#
#
#
#         Date: 05 Sep, 2025 11:01am
#         Title: Heavy rains across Sindh from Sunday to Tuesday
#         Explanation: Torrential rains may cause urban flooding in low-lying areas, PMD warns.
#
#
#
#         Date: 05 Sep, 2025 10:56am
#         Title: Hundreds waiting to be rescued in Ahmedpur Sial
#         Explanation: Local politician alleges that situation created due to wrong breach; Jhang district administration says over 100 boats being used in rescue operations.
#
#
#
#         Date: 05 Sep, 2025 07:58am
#         Title: Accords worth $8.5bn signed during PM’s China visit
#
#         Explanation: Premier meets his counterpart, pledges close coordination on second phase of CPEC.
#
#
#
#         Date: 04 Sep, 2025 10:56pm
#         Title: Talk of ‘hybrid system’ is admission of dictatorship: Justice Minallah
#         Explanation: Blames "lack of constitutional governance" for country’s elite capture; Khawaja Asif responds.
#
#
#
#         Date: 04 Sep, 2025 11:09pm
#         Title: Tremors of 5.9-magnitude earthquake felt in twin cities, KP: PMD
#         Explanation: Originated at 9:56pm at a depth of 111 kilometres with its epicentre in the Hindu Kush region, Punjab PDMA says no damage reported so far.
#
#
#
#         Date: 04 Sep, 2025 08:07pm
#         Title: Mustafa Khokhar moves Supreme Court to fix pending petitions challenging 26th Amendment
#         Explanation: Petitioner contends that SC committee's decision is legally binding, and ignoring it amounts to administrative impropriety.
#
#
#
#         Date: 04 Sep, 2025 07:29pm
#         Title: Lahore ATC also grants bail to Imran Khan’s nephew Shershah in May 9 riots case
#         Explanation: Counsel notes prosecution has still not produced case record against Shershah as bail approved against Rs100,000 surety bond; Shahrez released after paying bail.
#
#
#
#         Date: 04 Sep, 2025 09:20am
#         Title: Supreme Court Bar Association for open hearing of plaints against judges
#         Explanation: Set of proposals made public ahead of SC full court meeting.
#
#
#
#         Date: 04 Sep, 2025 01:26pm
#         Title: Floods in GB’s Diamer district damage at least 20 houses, crops, trees: authorities
#         Explanation: Locals say many people fled and moved to safer places when the flood hit.
#
#
#
#         Date: 04 Sep, 2025 09:16am
#         Title: Opposition alliance rails against Punjab govt’s flood relief efforts
#
#         Explanation: TTAP accuses officials of using relief efforts to run media campaign for CM Maryam.
#
#
#
#         Date: 05 Sep, 2025 06:10pm
#         Title: PSX crosses 154,000 points amid investor optimism despite flood-related risks
#         Explanation: Analyst notes "incipient euphoria", cautions against underestimating flood-related concerns.
#
#
#
#         Date: 05 Sep, 2025 10:02am
#         Title: Floods spark agri-emergency call as vast rice, cotton crops ruined with losses ‘in billions’
#         Explanation: Pakistan Business Forum warns 60pc of rice, 35pc of cotton and 30pc of sugarcane lost in Punjab; calls for loans, reforms.
#
#
#
#         Date: 05 Sep, 2025 10:35am
#         Title: Ex-PM Shahid Khaqan Abbasi blames govt for sugar crisis
#         Explanation: Accuses NAB of protecting corrupt business practices instead of holding mill owners accountable.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: Services exports rise 18.3pc in July
#
#         Explanation: IT-related services lead a 23.8pc rise in telecom, computer, and information exports.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: VEON to acquire TPL Insurance
#
#         Explanation: Acquisition will enable Jazz to offer tailored insurance products.
#
#
#
#         Date: 05 Sep, 2025 10:03am
#         Title: Maritime joint ventures with China explored
#         Explanation: Shandong Xinxu proposes integrated maritime complex in Pakistan.
#
#
#
#         Date: 05 Sep, 2025 09:45am
#         Title: UK, UN announce aid as country reels from floods
#         Explanation: UK announces another £1.2m for Sindh; UN allocates $600,000 from Regional Humanitarian Fund.
#
#
#
#         Date: 05 Sep, 2025 02:01pm
#         Title: K-Electric sukuk IPO oversubscribed by 2.2 times; raises Rs2bn
#         Explanation: Utility terms sukuk IPO "significant step" towards Islamic finance at household and individual level.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: SBP reserves rise by $28m to $14.3bn
#
#         Explanation: Increase reflects growing stability in country’s external account.
#
#
#
#         Date: 05 Sep, 2025 10:29am
#         Title: PSX hits new highs despite flood concerns
#
#         Explanation: Index gains 464 po­­ints, maint­a­ining its upward trajectory amid strong institutional interest and positive economic signals.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: PPL strikes major oil, gas discovery
#
#         Explanation: Company terms discovery "major milestone for both PPL and its joint venture partner".
#
#
#
#         Date: 05 Sep, 2025 07:58am
#         Title: Accords worth $8.5bn signed during PM’s China visit
#
#         Explanation: Premier meets his counterpart, pledges close coordination on second phase of CPEC.
#
#
#
#         Date: 04 Sep, 2025 11:47pm
#         Title: PM Shehbaz, Chinese premier reaffirm working on CPEC 2.0 as firms ink 21 MoUs
#         Explanation: Pacts signed in science and technology, media, agriculture; over 300 Pakistani and 500 Chinese companies attend B2B conference.
#
#
#
#         Date: 04 Sep, 2025 01:36pm
#         Title: Global funding cuts to force 6m more children out of school in 2026: Unicef
#         Explanation: Twenty-eight countries are projected to lose at least a quarter of the education assistance for pre-primary, primary, and secondary schooling.
#
#
#
#         Date: 04 Sep, 2025 09:43am
#         Title: Wapda seeks 91pc increase in revenue requirement to Rs365 billion
#         Explanation: Would translate into an estimated 90pc increase in bulk hydropower rate to about Rs11.55 per unit.
#
#
#
#         Date: 04 Sep, 2025 09:53am
#         Title: Unexpected rise in cotton arrivals despite floods
#
#         Explanation: Lint production increases by 9pc driven mainly by a surge in Sindh.
#
#
#
#         Date: 04 Sep, 2025 09:37am
#         Title: Senate committee proposes key changes to Virtual Assets Bill
#
#         Explanation: Recommends barring PVARA members from trading; proposes placing authority under Finance Division.
#
#
#
#         Date: 04 Sep, 2025 07:20am
#         Title: Gold hits record Rs376,000 per tola
#
#         Explanation: Marks an increase of Rs5,144; silver price also rises.
#
#
#
#         Date: 04 Sep, 2025 09:58am
#         Title: Govt raises Rs515bn as banks overbid
#
#         Explanation: Despite excess liquidity, slow credit flow to private sector raises concerns.
#
#
#
#         Date: 04 Sep, 2025 09:55am
#         Title: Cement, fertiliser power PSX to new peak
#
#         Explanation: KSE-100 index settles above 152,000 points despite economic challenges.
#
#
#
#         Date: 04 Sep, 2025 10:55am
#         Title: Envoy Natalie Baker urges US firms to invest in Pakistan
#         Explanation: Emphasises Pakistan’s large consumer market, competitive labour costs, and strategic location.
#
#
#
#         Date: 04 Sep, 2025 11:24am
#         Title: Parliament to take up bill to give legal cover to employees regularised during PPP govt
#
#         Explanation: Brief shows move will not have any additional financial impact on national kitty.
#
#
#
#         Date: 03 Sep, 2025 08:40pm
#         Title: Business tycoon, renowned philanthropist Rafiq M. Habib passes away at 88
#         Explanation: Former House of Habib head passes away in Dubai; remembered for "humility and steadfast service".
#
#
#
#         Date: 03 Sep, 2025 09:26am
#         Title: Exports fall 12.5pc as demand dips in August
#
#         Explanation: PBS data shows export proceeds declined by 9.98pc on month-on-month basis.
#
#
#
#         Date: 03 Sep, 2025 09:29am
#         Title: SBP chief sees GDP expanding 3.25-4.25pc
#
#         Explanation: Textile Council urges EFS revival, cost cuts amid US tariffs on Indian exports.
#
#
#
#         Date: 03 Sep, 2025 09:35am
#         Title: Neelum-Jhelum project ‘a failure of planning, execution’
#
#         Explanation: Auditor general's report finds Rs507bn scheme plagued by tunnel collapses, delays and cost overruns.
#
#
#
#         Date: 03 Sep, 2025 09:42am
#         Title: Senate panel warns IT ministry over telecom boards’ secrecy
#
#         Explanation: Orders provision of required information in next meeting.
#
#
#
#         Date: 03 Sep, 2025 09:46am
#         Title: Flour millers blame Punjab ban for  wheat crisis
#
#         Explanation: Warn that stored wheat in flood-affected areas could be destroyed if not moved promptly to safer locations in other provinces.
#
#
#
#         Date: 03 Sep, 2025 09:50am
#         Title: Google keeps Chrome and Apple deal but must share data in big antitrust ruling
#         Explanation: Google faces a major threat from increasingly popular AI tools, including OpenAI’s popular ChatGPT chatbot, which are already eroding Google’s dominance.
#
#
#
#         Date: 03 Sep, 2025 05:47am
#         Title: Construction activity spurs cement demand
#
#         Explanation: Total despatches rose 21pc in July-August FY25.
#
#
#
#         Date: 03 Sep, 2025 10:00am
#         Title: Paperboard industry warns of dumping risk
#
#         Explanation: Seeks import price revision to avert job, factory losses.
#
#
#
#         Date: 03 Sep, 2025 10:09am
#         Title: PTCL, Link Dot pay fines in ICH ruling
#
#         Explanation: Recovery includes Rs458m from PTCL and Rs37m from Link Dot Net.
#
#
#
#         Date: 03 Sep, 2025 10:15am
#         Title: Urea sales surge 46pc in August
#         Explanation: Rise driven by aggressive discounting by select manufacturers, dealer pre-buying ahead of partial rollback in September.
#
#
#
#         Date: 03 Sep, 2025 10:18am
#         Title: PSX defies flood concerns, hits new peak
#
#         Explanation: Analyst attributes bullish close to a combination of upbeat economic indicators.
#
#
#
#         Date: 02 Sep, 2025 10:18pm
#         Title: Saudi Aramco, Iraq’s SOMO halt crude sales to Indian refiner Nayara, sources say
#         Explanation: The halting of supply from the two Gulf exporters means Nayara relied entirely on Russia for its crude oil imports in August.
#
#
#
#         Date: 05 Sep, 2025 09:50pm
#         Title: Hamas decries Israel’s intensified attacks on Gaza City as day’s death toll rises to 51
#         Explanation: Palestinian NGOs vow to continue cooperation with ICC after US sanctions; UK urged to implement measures over Israel’s war on Gaza.
#
#
#
#         Date: 05 Sep, 2025 07:08pm
#         Title: WHO chief lifts global mpox emergency
#         Explanation: Dr Tedros Adhanom Ghebreyesus says decision taken in light of declining cases and deaths.
#
#
#
#         Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer
#         Explanation: With Labour trailing Nigel Farage's populist Reform UK in the polls, UK PM Starmer faces difficult state spending and tax choices.
#
#
#
#         Date: 05 Sep, 2025 06:54pm
#         Title: Trump says India and Russia appear ‘lost’ to ‘deepest, darkest China’
#         Explanation: Asked about Trump’s post, Indian foreign ministry spokesperson says he has no comment; India plans relief package for exporters hit by US tariffs.
#
#
#
#         Date: 05 Sep, 2025 09:41am
#         Title: Trump rebrands Department of Defence as ‘Department of War’
#         Explanation: According to the White House, the name change “conveys a stronger message of readiness and resolve".
#
#
#
#         Date: 05 Sep, 2025 07:05pm
#         Title: ‘Roblox’ game to impose age controls this year
#         Explanation: Company aims to combine estimates of users' ages, checks on official IDs and parental consent to limit communication between adults and minors.
#
#
#
#         Date: 05 Sep, 2025 08:01am
#         Title: ‘Deadliest in decades’ Afghan quake toll tops 2,200
#
#         Explanation: Separate 6.2-magnitude tremor strikes southeastern part of country; search operations continue in quake-hit areas.
#
#
#
#         Date: 05 Sep, 2025 12:11pm
#         Title: Death toll rises to 16 in Lisbon funicular crash
#
#         Explanation: The dead included two South Koreans and a Swiss national; 11 foreigners were among the injured.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: UN body finds US, UAE responsible for Afghan refugee’s arbitrary detention
#
#         Explanation: 5-member Working Group asks both states to provide compensation and reparations.
#
#
#
#         Date: 05 Sep, 2025 12:02pm
#         Title: Trump tells Europe to put economic pressure on China
#
#         Explanation: Zelensky says discussed sanctions on Russia and protecting Ukraine’s airspace in call.
#
#
#
#         Date: 05 Sep, 2025 09:30am
#         Title: Yamuna crosses danger mark as heavy rains flood Delhi
#
#         Explanation: Muddy water pours into many homes in low-lying areas; people wade through floodwaters in areas surrounding historic Red Fort.
#
#
#
#         Date: 05 Sep, 2025 08:53am
#         Title: US judge overturns Trump funding cuts to Harvard
#
#         Explanation: "Court vacates and sets aside the Freeze Ord­ers and Termination Let­ters as violative of the Fir­st Amendment," order notes.
#
#
#
#         Date: 05 Sep, 2025 06:25am
#         Title: Norway tests electric plane
#
#         Explanation: Flight takes 55 minutes and simulated a cargo flight route in south-eastern Norway.
#
#
#
#         Date: 05 Sep, 2025 08:23am
#         Title: Israel kills 53, claims control over ‘40pc  of Gaza City’
#
#         Explanation: Pope raises “tragic situation in Gaza” with Israeli president; top European official slams bloc’s inaction over "genocide" of Palestinians.
#
#
#
#         Date: 05 Sep, 2025 07:58am
#         Title: Accords worth $8.5bn signed during PM’s China visit
#
#         Explanation: Premier meets his counterpart, pledges close coordination on second phase of CPEC.
#
#
#
#         Date: 04 Sep, 2025 11:54pm
#         Title: 26 nations vow to give Ukraine postwar security guarantees, Macron says
#         Explanation: “The day the conflict stops, the security guarantees will be deployed,” French president says.
#
#
#
#         Date: 04 Sep, 2025 08:46pm
#         Title: Search teams retrieve bodies as Afghan quake toll rises to over 2,200
#         Explanation: WHO appeals for $4 million in earthquake relief.
#
#
#
#         Date: 04 Sep, 2025 04:47pm
#         Title: China denies conspiring with North Korea, Russia against US
#         Explanation: "Give my warmest regards to Vladimir Putin, and Kim Jong Un, as you conspire against The United States of America," Trump had said in a social media post, addressing the Chinese president.
#
#
#
#         Date: 04 Sep, 2025 05:38pm
#         Title: Pakistan, Qatar reaffirm commitment to regional peace and stability
#         Explanation: Qatari military leadership lauds Pakistan's role in "ensuring regional stability", says  ISPR.
#
#
#
#         Date: 04 Sep, 2025 11:47pm
#         Title: PM Shehbaz, Chinese premier reaffirm working on CPEC 2.0 as firms ink 21 MoUs
#         Explanation: Pacts signed in science and technology, media, agriculture; over 300 Pakistani and 500 Chinese companies attend B2B conference.
#
#
#
#         Date: 04 Sep, 2025 01:36pm
#         Title: Global funding cuts to force 6m more children out of school in 2026: Unicef
#         Explanation: Twenty-eight countries are projected to lose at least a quarter of the education assistance for pre-primary, primary, and secondary schooling.
#
#
#
#         Date: 04 Sep, 2025 11:08am
#         Title: Stargazers to witness rare ‘Blood Moon’ during total lunar eclipse across Asia, Europe, and Africa on Sunday
#         Explanation: People in Asia, including India and China, will be best placed to see Sunday’s total eclipse.
#
#
#
#         Date: 04 Sep, 2025 11:45am
#         Title: Jeffrey Epstein victims compiling own list of abusers
#         Explanation: Trump calls the furor a "Democrat hoax that never ends".
#
#
#
#         Date: 04 Sep, 2025 08:17am
#         Title: UN seeks halt to deportations amid Afghan quake relief
#
#         Explanation: Kunar is the worst-hit province; commandos sent to look for survivors; WFP says it has supplies, funds for only 4 weeks.
#
#
#
#         Date: 04 Sep, 2025 07:18am
#         Title: Xi offers ‘war or peace’ as China flexes military might
#
#         Explanation: PM Shehbaz meets Chinese businessmen, tours Beijing’s Anzhen Hospital.
#
#
#
#         Date: 04 Sep, 2025 09:24am
#         Title: US lawmakers briefed on flood devastation in Pakistan
#
#         Explanation: Pakistani Americans highlight urgent need for food, clean water, medical aid and rehabilitation for millions hit by floods.
#
#
#
#         Date: 04 Sep, 2025 11:54am
#         Title: Israel drops grenades near peacekeepers in Lebanon
#
#         Explanation: UN force slams drone attack as “one of the most serious” since November ceasefire.
#
#
#
#         Date: 04 Sep, 2025 08:12am
#         Title: Israeli annexation in West Bank is ‘red line’, warns UAE
#
#         Explanation: 24 Palestinians killed as military pushes further into Gaza City; UN Committee on the Rights of Persons says 21,000 children disabled in conflict.
#
#
#
#         Date: 03 Sep, 2025 11:10pm
#         Title: Trump says he plans to hold talks on Ukraine in coming days
#         Explanation: Putin tells Ukraine to end the war via talks or he will end it by force.
#
#
#
#         Date: 03 Sep, 2025 04:39pm
#         Title: China ‘unstoppable’, says Xi with Shehbaz, Kim and Putin at his side
#         Explanation: ICBMs, hypersonic missiles and underwater drones among Chinese weaponry on display.
#
#
#
#         Date: 03 Sep, 2025 09:30pm
#         Title: Pakistan dispatches 105 tonnes of humanitarian aid for quake struck Afghanistan
#         Explanation: Afghanistan airdrops commandos to pull survivors from rubble as UN agency warns that food aid would run out soon without funding.
#
#
#
#         Date: 04 Sep, 2025 11:40am
#         Title: Dhaka eyes end to mystery of last Nawab’s treasure trove
#
#         Explanation: Locked away in 1908, were the family’s heirlooms lost in 1947 or did they survive the 1971 events and remain safe in the bank vault?
#
#
#
#         Date: 03 Sep, 2025 05:13pm
#         Title: Heavy rain lashes northern India, Yamuna river breaches danger mark in Delhi
#         Explanation: The swollen rivers have triggered landslides and damaged many roads.
#
#
#
#         Date: 03 Sep, 2025 02:24pm
#         Title: 11 dead as US forces strike ‘drug vessel’ off Venezuela
#         Explanation: Eight US Navy vessels currently involved in counter-narcotics operations in Latin America.
#
#
#
#         Date: 03 Sep, 2025 10:45am
#         Title: Republican US House committee releases thousands of Epstein files
#         Explanation: Trump's party leadership looks to end push by bipartisan pair of lawmakers to force a vote on releasing all records.
#
#
#
#         Date: 05 Sep, 2025 07:50pm
#         Title: Afghanistan opt to bat first against UAE in T20 tri-series penultimate match
#         Explanation: Pakistan have already entered the final after beating the UAE twice and Afghanistan once.
#
#
#
#         Date: 05 Sep, 2025 10:50am
#         Title: Sabalenka returns to US Open final as Anisimova sinks Osaka
#         Explanation: The 27-year-old from Belarus is through to her third successive US Open final.
#
#
#
#         Date: 05 Sep, 2025 10:43am
#         Title: Fakhar and Abrar star as Pakistan beat UAE to reach tri-series final
#
#         Explanation: The win not only took Pakistan to Sunday’s final but also ensured Afghanistan who face the hosts in the last group on Friday, would advance.
#
#
#
#         Date: 05 Sep, 2025 04:13pm
#         Title: Powerhouse Australia ‘up for challenge’ of defending ICC Women’s World Cup
#         Explanation: National selector says extended nature of ODI World Cup can be a challenge but group has depth and versatility to meet those demands.
#
#
#
#         Date: 05 Sep, 2025 02:19pm
#         Title: Daniel Levy makes shock decision to quit as Tottenham chairman after nearly 25 years
#         Explanation: Levy, who was the longest-serving chairman in the Premier League, had come under fire more than ever over the last few seasons.
#
#
#
#         Date: 05 Sep, 2025 06:00am
#         Title: ‘Why not us?’: Pakistan’s ice hockey teams defied odds to deliver glory — and there’s more to come
#         Explanation: In Florida, the teams' journeys are a testament to love, identity, and the audacious belief that some dreams are worth chasing, no matter how impossible they seem.
#
#
#
#         Date: 05 Sep, 2025 12:44pm
#         Title: Floyd Mayweather Jr, Mike Tyson agree to exhibition fight in 2026
#         Explanation: Boxing legends Floyd Mayweather Jr. and Mike Tyson are set to square off in an exhibition boxing match next spring,...
#
#
#
#         Date: 05 Sep, 2025 11:34am
#         Title: FIFA to use dynamic pricing for World Cup ticket sales
#
#         Explanation: Tickets for group-stage matches will start at $60, with pricing for later stages, including the final, reaching up to $6,730.
#
#
#
#         Date: 04 Sep, 2025 01:40pm
#         Title: India’s Neeraj Chopra needs more than just consistency for another gold at the world championships
#         Explanation: The Indian has fallen well short of 90m in his last five outings and threw a modest 85.01m in the Diamond League Final in Zurich last week.
#
#
#
#         Date: 04 Sep, 2025 05:28pm
#         Title: Australia excited as teen sprinter Gout makes world championships debut
#         Explanation: Still only 17, Gout is already one of the most exciting prospects in global athletics, earning comparisons with Jamaican great Usain Bolt and training with Adidas stable-mate Noah Lyles in Florida.
#
#
#
#         Date: 04 Sep, 2025 10:45am
#         Title: Sinner powers into US Open semis, Anisimova gains Swiatek revenge
#         Explanation: Canadian Auger-Aliassime overcame Alex de Minaur in a four-set battle lasting over four hours to reach his second US Open semi-final.
#
#
#
#         Date: 04 Sep, 2025 03:01pm
#         Title: French women’s boxing team barred from world champs over late gender test
#         Explanation: Boxing federation says athletes from France, other countries "have been caught in this trap and excluded.”
#
#
#
#         Date: 04 Sep, 2025 10:59am
#         Title: ‘India, Pakistan may not host hockey events unless normal political ties established’
#
#         Explanation: Sources warn PHF not to officially boycott Junior World Cup being held in India, as it would compel the FIH to penalise Pakistan.
#
#
#
#         Date: 04 Sep, 2025 11:12am
#         Title: Iraq thrash 10-man Pakistan 8-1 in AFC Under-23 Asian Cup qualifying campaign
#         Explanation: Iraq, the 2013 champions, increased their lead soon after the break with Jasim getting his first in the 47th.
#
#
#
#         Date: 04 Sep, 2025 12:13pm
#         Title: Nissanka stars SL beat Zimbabwe in first T20
#
#         Explanation: After Nissanka played a pivotal role with a half century and a century in a 2-0 ODI series victory, he proved equally successful in the shorter format.
#
#
#
#         Date: 04 Sep, 2025 12:24pm
#         Title: Ugandan stars Jacob Kiplimo, Joshua Cheptegei to miss World Athletics Championships
#         Explanation: Uganda’s Olympic Committee president says decision was "unfortunate" but are are respecting their personal reasons.
#
#
#
#         Date: 03 Sep, 2025 05:50pm
#         Title: Boxer Imane Khelif not competing at world championships amid sex testing appeal
#         Explanation: World Boxing says too early to draw conclusions about whether the Algerian failed the mandatory sex test.
#
#
#
#         Date: 03 Sep, 2025 10:07am
#         Title: Djokovic sets up Alcaraz US Open blockbuster as Sabalenka advances
#         Explanation: Defending champion Sabalenka moves into semi-finals after Czech quarter-final opponent Marketa Vondrousova pulls out with a knee injury.
#
#
#
#         Date: 03 Sep, 2025 11:20am
#         Title: ‘I thought 170 was gettable’, skipper Salman rues after Afghanistan thrashing in tri-series match
#         Explanation: Pakistan had beaten Afghanistan in the tri-series opener on Friday but were second best this time.
#
#
#
#         Date: 03 Sep, 2025 04:14pm
#         Title: Australia captain Pat Cummins ‘doing everything’ to be fit for Ashes opener
#         Explanation: Says it would be “devastating” to miss out on the Perth clash against England.
#
#
#
#         Date: 03 Sep, 2025 02:11pm
#         Title: PHF chief rules out Pakistan’s participation in Jr World Cup amid tensions with India
#         Explanation: President acknowledges that not participating in intl events in India was hurting country’s hockey but national cause was bigger than everything.
#
#
#
#         Date: 03 Sep, 2025 11:31am
#         Title: After ‘high intensity’ training, Pakistan begin AFC Under-23 campaign
#
#         Explanation: Assistant coach Gohar believes working on improving fitness levels could help Paki­stan as they take on Iraq in their Group ‘G’ opener.
#
#
#
#         Date: 03 Sep, 2025 02:05pm
#         Title: Pakistan’s Shoaib to fight Indian boxer in Istanbul
#         Explanation: Shoaib who has already impressed in global contests, said his training had been tailored for endurance and speed.
#
#
#
#         Date: 03 Sep, 2025 05:47am
#         Title: Glory, survival drive EPL’s record £3bn transfer splurge
#
#         Explanation: Gross spending for the Premier League this season is already the highest ever, exceeding the 2.7 billion pounds spent in the 2022-23 season.
#
#
#
#         Date: 02 Sep, 2025 05:50pm
#         Title: Asif Ali announces retirement from international cricket
#         Explanation: Asif, 33, made his T20I debut against West Indies in April 2018 after helping Islamabad United win the PSL that year.
#
#
#
#         Date: 02 Sep, 2025 03:38pm
#         Title: Taiwanese Olympic boxer Lin won’t compete at world championships amid gender row
#         Explanation: The 29-year-old Lin Yu-ting had agreed to undergo testing mandated by World Boxing last month.
#
#
#
#         Date: 02 Sep, 2025 06:57pm
#         Title: US Olympic champion Gabby Thomas to miss World Athletics Championships due to injury
#         Explanation: “As an athlete, you always want to keep grinding, but sometimes you simply can’t outwork an injury,” the 28-year-old said.
#
#
#
#         Date: 02 Sep, 2025 09:52am
#         Title: Australia pace great Mitchell Starc retires from T20 international cricket
#         Explanation: The 35-year-old left-armer retires as the nation’s most prolific fast bowler in the format, with 79 wickets from 65 T20Is.
#
#
#
#         Date: 02 Sep, 2025 11:23am
#         Title: US Open underdogs Naomi Osaka, Felix Auger-Aliassime storm into quarter-finals
#         Explanation: Iga Swiatek continued her incredible season with a 6-3 6-1 thumping of 13th seed Ekaterina Alexandrova in 64 minutes.
#
#
#
#         Date: 02 Sep, 2025 02:19pm
#         Title: Australia hopeful on Cummins fitness for Ashes despite back issue
#         Explanation: The Test skipper has been struggling with the issue since July and the Ashes start in November.
#
#
#
#         Date: 02 Sep, 2025 01:32pm
#         Title: Ederson leaves Man City for Fenerbahce after eight trophy-laden years
#         Explanation: The Brazilian goalkeeper has won the Premier League Golden Glove award three times.
#
#
#
#         Date: 02 Sep, 2025 11:39am
#         Title: Skipper Rashid Khan sets T20 record as Afghanistan beat UAE
#         Explanation: Afghanistan’s total of 188-4 was built around a brilliant 40-ball 63 from Ibrahim Zadran and a 40-ball 54 by Sediqullah Atal.
#
#
#
#         Date: 02 Sep, 2025 01:10pm
#         Title: Imane Khelif appeals to CAS against World Boxing ban over genetic testing
#         Explanation: Appeal seeks to overturn ruling and allow Algeria’s Khelif to compete at 2025 World Boxing Championships without having the test.
#
#
#
#         Date: 02 Sep, 2025 01:06pm
#         Title: Former heavyweight Joe Bugner, who fought Ali twice, dies at 75
#         Explanation: Bugner’s professional boxing career spanned 32 years and 83 bouts, of which he won 69, including 41 by knockout.
#
#
#
#         Date: 01 Sep, 2025 07:03pm
#         Title: Afghan Cricket Board calls for support from business community for quake victims
#         Explanation: Minute of silence to be observed before start of UAE-Afghanistan tri-series match today; Zalmi Foundation pledges Rs10m to quake victims.

# %%
# Method 1: Character-based splitting
print("1️⃣ CHARACTER TEXT SPLITTER")
char_splitter = CharacterTextSplitter(
    separator="\n",  # Split on newlines
    chunk_size=270,  # Max chunk size in characters
    chunk_overlap=1,  # Overlap between chunks
    length_function=len  # How to measure chunk size
)

char_chunks=char_splitter.split_text(text)
print(f"Created {len(char_chunks)} chunks")
print(f"First chunk: {char_chunks[0]}")
# Out:
# 1️⃣ CHARACTER TEXT SPLITTER
# Created 216 chunks
# First chunk: Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer

# %%
print(char_chunks[0])
print("------------------")
print(char_chunks[1])
print("------------------")
print(char_chunks[2])
print("------------------")
print(char_chunks[3])
# Out:
# Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer
# ------------------
# Explanation: With Labour trailing Nigel Farage's populist Reform UK in the polls, UK PM Starmer faces difficult state spending and tax choices.
#
#
#         Date: 05 Sep, 2025 09:40pm
# ------------------
# Title: Justice Shah asks CJP Afridi to publicly answer 6 questions on ‘pressing institutional concerns’
# ------------------
# Explanation: Says he trusts CJP to use Sept 8 judicial conference as a “moment of institutional renewal by answering these questions and reaffirming the principles of collegiality and constitutional fidelity”.
#
#
#         Date: 05 Sep, 2025 07:25pm

# %%
# Method 1: Character-based splitting
print("1️⃣ CHARACTER TEXT SPLITTER")
char_splitter = CharacterTextSplitter(
    separator="\n",  # Split on newlines
    chunk_size=300,  # Max chunk size in characters
    chunk_overlap=20,  # Overlap between chunks
    length_function=len  # How to measure chunk size
)

char_chunks=char_splitter.split_text(text)
print(f"Created {len(char_chunks)} chunks")
print(f"First chunk: {char_chunks[0][:1000]}...")
# Out:
# 1️⃣ CHARACTER TEXT SPLITTER
# Created 194 chunks
# First chunk: Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer
#         Explanation: With Labour trailing Nigel Farage's populist Reform UK in the polls, UK PM Starmer faces difficult state spending and tax choices....

# %%
print(char_chunks[0])
print("-------------")
print(char_chunks[1])
print("-------------")
print(char_chunks[2])
# Out:
# Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer
#         Explanation: With Labour trailing Nigel Farage's populist Reform UK in the polls, UK PM Starmer faces difficult state spending and tax choices.
# -------------
# Date: 05 Sep, 2025 09:40pm
#         Title: Justice Shah asks CJP Afridi to publicly answer 6 questions on ‘pressing institutional concerns’
# -------------
# Explanation: Says he trusts CJP to use Sept 8 judicial conference as a “moment of institutional renewal by answering these questions and reaffirming the principles of collegiality and constitutional fidelity”.
#
#
#         Date: 05 Sep, 2025 07:25pm

# %%
# Method 2: Recursive character splitting (RECOMMENDED)
print("\n2️⃣ RECURSIVE CHARACTER TEXT SPLITTER")
recursive_splitter = RecursiveCharacterTextSplitter(
    separators=[" "],  # Try these separators in order
    chunk_size=250,
    chunk_overlap=20,
    length_function=len
)

recursive_chunks = recursive_splitter.split_text(text)
print(f"Created {len(recursive_chunks)} chunks")
print(f"First chunk: {recursive_chunks[0][:100]}...")
# Out:
# 2️⃣ RECURSIVE CHARACTER TEXT SPLITTER
# Created 216 chunks
# First chunk: Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging b...

# %%
print(recursive_chunks[0])
print("-----------------")
print(recursive_chunks[1])
print("------------------")
print(recursive_chunks[2])
# Out:
# Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer
#         Explanation: With Labour trailing Nigel Farage's populist Reform UK in the polls, UK PM Starmer faces difficult state
# -----------------
# difficult state spending and tax choices.
#
#
#
#         Date: 05 Sep, 2025 09:40pm
#         Title: Justice Shah asks CJP Afridi to publicly answer 6 questions on ‘pressing institutional concerns’
#         Explanation: Says he trusts CJP to use Sept
# ------------------
# CJP to use Sept 8 judicial conference as a “moment of institutional renewal by answering these questions and reaffirming the principles of collegiality and constitutional fidelity”.
#
#
#
#         Date: 05 Sep, 2025 07:25pm
#         Title: Imran

# %% [markdown]
# ## Overlapping is good to happen because this can be helpful to pull all the related chunks needed.

# %% [markdown]
# ### There is the overlapping between the chunks. Becuase there in only one separator(Space) is been used.

# %%
# Create text without natural break points
simple_text = "This is sentence one and it is quite long. This is sentence two and it is also quite long. This is sentence three which is even longer than the others. This is sentence four. This is sentence five. This is sentence six."

splitter = RecursiveCharacterTextSplitter(
    separators=[" "],  # Only split on spaces
    chunk_size=80,
    chunk_overlap=20,
    length_function=len
)

chunks = splitter.split_text(simple_text)

print(f"\nSimple text example - {len(chunks)} chunks:\n")

for i in range(len(chunks) - 1):
    print(f"Chunk {i+1}: '{chunks[i]}'")
    print(f"Chunk {i+2}: '{chunks[i+1]}'")
    
    
    print()
# Out:
# Simple text example - 4 chunks:
#
# Chunk 1: 'This is sentence one and it is quite long. This is sentence two and it is also'
# Chunk 2: 'two and it is also quite long. This is sentence three which is even longer than'
#
# Chunk 2: 'two and it is also quite long. This is sentence three which is even longer than'
# Chunk 3: 'is even longer than the others. This is sentence four. This is sentence five.'
#
# Chunk 3: 'is even longer than the others. This is sentence four. This is sentence five.'
# Chunk 4: 'is sentence five. This is sentence six.'

# %%
# Method 3: Token-based splitting
print("\n3️⃣ TOKEN TEXT SPLITTER")
token_splitter = TokenTextSplitter(
    chunk_size=50,  # Size in tokens (not characters)
    chunk_overlap=10
)

token_chunks = token_splitter.split_text(text)
print(f"Created {len(token_chunks)} chunks")
print(f"First chunk: {token_chunks[0][:1000]}...")
# Out:
# 3️⃣ TOKEN TEXT SPLITTER
# Created 416 chunks
# First chunk:
#         Date: 05 Sep, 2025 09:03pm
#         Title: UK deputy PM Rayner resigns over tax mistake in damaging blow to Starmer
#      ...

# %% [markdown]
# ### CharacterTextSplitter:
#   ✅ Simple and predictable
#   ✅ Good for structured text
#   ❌ May break mid-sentence
#   Use when: Text has clear delimiters
#
# ### RecursiveCharacterTextSplitter:
#   ✅ Respects text structure
#   ✅ Tries multiple separators
#   ✅ Best general-purpose splitter
#   ❌ Slightly more complex
#   Use when: Default choice for most texts
#
# ### TokenTextSplitter:
#   ✅ Respects model token limits
#   ✅ More accurate for embeddings
#   ❌ Slower than character-based
#   Use when: Working with token-limited models
